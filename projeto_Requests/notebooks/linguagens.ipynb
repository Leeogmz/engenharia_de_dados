# %%
import requests

# %%
r = requests.get('https://api.github.com/events')

# %%
r
# Out:
# <Response [200]>

# %%
r.status_code
# Out:
# 200

# %%
r.url
# Out:
# 'https://api.github.com/events'

# %%
r.text
# Out:
# '[{"id":"38736584696","type":"IssueCommentEvent","actor":{"id":41898282,"login":"github-actions[bot]","display_login":"github-actions","gravatar_id":"","url":"https://api.github.com/users/github-actions[bot]","avatar_url":"https://avatars.githubusercontent.com/u/41898282?"},"repo":{"id":30675533,"name":"google/fonts","url":"https://api.github.com/repos/google/fonts"},"payload":{"action":"created","issue":{"url":"https://api.github.com/repos/google/fonts/issues/7768","repository_url":"https://api.github.com/repos/google/fonts","labels_url":"https://api.github.com/repos/google/fonts/issues/7768/labels{/name}","comments_url":"https://api.github.com/repos/google/fonts/issues/7768/comments","events_url":"https://api.github.com/repos/google/fonts/issues/7768/events","html_url":"https://github.com/google/fonts/pull/7768","id":2318743468,"node_id":"PR_kwDOAdQSTc5wpEMW","number":7768,"title":"Alumni Sans SC: Version 1.016 added\\n\\n","user":{"login":"simoncozens","id":106728,"node_id":"MDQ6V
# ...

# %%
r.json()
# Out:
# [{'id': '38736584696',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 30675533,
#    'name': 'google/fonts',
#    'url': 'https://api.github.com/repos/google/fonts'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/google/fonts/issues/7768',
#     'repository_url': 'https://api.github.com/repos/google/fonts',
#     'labels_url': 'https://api.github.com/repos/google/fonts/issues/7768/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/google/fonts/issues/7768/comments',
#     'events_url': 'https://api.github.com/repos/google/fonts/issues/7768/events',
#     'html_url': 'https://github.com/google/fonts/pull/7768',
#     'id': 2318743468,
# ...

# %%
r = requests.get('https://api.github.com/versions')
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# ['2022-11-28']
